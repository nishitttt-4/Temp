# %%
! pip install qiskit
# Out:
# Requirement already satisfied: qiskit in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (2.1.1)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit) (1.16.2)
# Requirement already satisfied: dill>=0.3 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit) (0.3.6)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit) (5.4.1)
# Requirement already satisfied: typing-extensions in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit) (4.15.0)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from stevedore>=3.0.0->qiskit) (7.0.0)
# Requirement already satisfied: setuptools in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit) (69.5.1)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install qiskit_aer
# Out:
# Collecting qiskit_aer
#   Downloading qiskit_aer-0.17.2-cp311-cp311-win_amd64.whl.metadata (8.5 kB)
# Requirement already satisfied: qiskit>=1.1.0 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit_aer) (2.1.1)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit_aer) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit_aer) (1.16.2)
# Requirement already satisfied: psutil>=5 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit_aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit_aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.0->qiskit_aer) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.3.6)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (5.4.1)
# Requirement already satisfied: typing-extensions in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (4.15.0)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit_aer) (7.0.0)
# Requirement already satisfied: setuptools in c:\users\omkar\appdata\local\programs\python\python311\lib\site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit>=1.1.0->qiskit_aer) (69.5.1)
# Downloading qiskit_aer-0.17.2-cp311-cp311-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.6 MB 989.2 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.3/9.6 MB 1.7 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.6 MB 2.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.9/9.6 MB 3.6 MB/s eta 0:00:02
#    ------------------------ --------------- 5.8/9.6 MB 4.6 MB/s eta 0:00:01
#    ------------------------ --------------- 5.8/9.6 MB 4.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.6 MB 4.1 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.6 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.6 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.6 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 3.7 MB/s  0:00:03
# Installing collected packages: qiskit_aer
# Successfully installed qiskit_aer-0.17.2
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from qiskit import QuantumRegister , ClassicalRegister , QuantumCircuit

# %%
from qiskit_aer import AerSimulator as aer

# %%
def random_number(n = 16):
    qr = QuantumRegister(n)
    cr = ClassivalRegister(n)
    circuit = QuantumCircuit(qr , cr)
    circuit.h(qr)
    circuit.measure(qr,cr)
    print(circuit.draw())
    return int(aer().run(circuit , shots = 1).result().get_counts().most_frequent() , 2)

# %%
print("
random_number()
